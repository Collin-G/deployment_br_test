# %%
import requests

url = 'http://127.0.0.1:5000/predict'
files = {'file': open('/home/collin/Documents/pyramid/mitdata/MIT_INTERVIEW_DATASET/Videos/P22.avi', 'rb')}  # Replace with your video file path

response = requests.post(url, files=files)
print(response.json())  # Print the response from the server

# %%
from platform import python_version

print(python_version())
# Out:
# 3.10.12

# %%
import requests

# Replace this with your actual ngrok URL
ngrok_url = 'https://26bd-135-0-212-218.ngrok-free.app/predict'  # Update with your ngrok URL

def test_flask_api(video_file_path):
    # Open the video file in binary mode
    with open(video_file_path, 'rb') as video_file:
        # Prepare the files dictionary
        # files = {'file': video_file}
        files = {'file': open(video_file_path, 'rb')}  # Replace with your video file path
        
        # Make the POST request to the Flask API
        response = requests.post(ngrok_url, files=files)

        # Print the status code and response
        print(f'Status Code: {response.status_code}')
        print('Response JSON:', response.json())

# Path to your test video file
#  '/tmp/tmp0btnkm0u.mp4'
test_video_path = '/tmp/tmp0btnkm0u.mp4' # Update with the path to your video file
test_flask_api(test_video_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 23
#      20 # Path to your test video file
#      21 #  '/tmp/tmp0btnkm0u.mp4'
#      22 test_video_path = '/tmp/tmp0btnkm0u.mp4' # Update with the path to your video file
# ---> 23 test_flask_api(test_video_path)
#
# Cell In[1], line 8, in test_flask_api(video_file_path)
#       6 def test_flask_api(video_file_path):
#       7     # Open the video file in binary mode
# ----> 8     with open(video_file_path, 'rb') as video_file:
#       9         # Prepare the files dictionary
#      10         # files = {'file': video_file}
#      11         files = {'file': open(video_file_path, 'rb')}  # Replace with your video file path
#      13         # Make the POST request to the Flask API
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmp0btnkm0u.mp4'

# %%
import imageio

def get_total_frames_imageio(video_file):
    reader = imageio.get_reader(video_file)
    total_frames = reader.count_frames()
    reader.close()  # Clean up resources
    return total_frames

# %%
import cv2
cap = cv2.VideoCapture('/tmp/tmp0btnkm0u.mp4')
fps = int(cap.get(cv2.CAP_PROP_FPS))  # Frames per secon
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
total_frames = get_total_frames_imageio("/tmp/tmp0btnkm0u.mp4")
print(total_frames, "total")
print(fps)
# Out:
# 950
# -276701161105643264 total
# 30

# %%
import dlib
import numpy as np

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

# Helper function to extract facial landmarks
def get_landmarks(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    faces = detector(gray)
    if len(faces) == 0:
        return None  # No face detected

    landmarks = predictor(gray, faces[0])  # Assuming 1 face per frame
    points = np.array([[p.x, p.y] for p in landmarks.parts()], dtype=np.float32)
    return points

# Process video and print landmark points for each frame
def process_video(video_path):
    cap = cv2.VideoCapture(video_path)
    total_frames = get_total_frames_imageio(video_path)
    print("Total frames:", total_frames)

    frame_count = 0  # To count processed frames

    while True:
        ret, frame = cap.read()
        if not ret:
            break  # End of video

        landmarks = get_landmarks(frame)
        frame_count += 1  # Increment the frame count
        # points = np.array([[p.x, p.y] for p in landmarks.parts()], dtype=np.float32)

        if landmarks is not None:
            # print(f"Frame {frame_count}: {landmarks}")  # Print landmarks for the current frame
            print(landmarks.shape)
        else:
            # print(f"Frame {frame_count}: No landmarks detected")
            print("no")

    cap.release()
    cv2.destroyAllWindows()

# %%
process_video("/tmp/tmpy2gybh_z.mp4")
# Out:
# Total frames: 181
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
# (68, 2)
